# %% [markdown]
# <a href="https://colab.research.google.com/github/Bhoomi-52/PredictionModelBhoomi/blob/main/Task2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn import svm
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression

# %%
#dataset 1:- Heart disease
df = pd.read_csv('/content/heart_disease_data.csv')

x = df.drop(['target'], axis=1)
y = df['target']

print("Head is: \n",df.head())
print("Shape is : \n",df.shape)
print(df.describe())
print(df['target'].value_counts())

xtrain,ytrain,xtest,ytest = train_test_split(x,y,test_size=0.2,random_state=2)

cf = svm.SVC(kernel='linear')
cf.fit(xtrain,xtest)

model = LogisticRegression()
model.fit(xtrain,xtest)

yprd = model.predict(ytrain)
score = accuracy_score(yprd,ytest)
print(score)
# Out:
# Head is:
#     age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1
# Shape is :
#  (303, 14)
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# ...

# %%
#Dataset 2:- Winequality
from sklearn.ensemble import RandomForestClassifier

df = pd.read_csv('/content/winequality.csv')

x = df.drop(['quality'], axis=1)
y = df['quality']

print("Head is: \n",df.head())
print("Shape is: \n",df.shape)
print(df.describe())
print(df['quality'].value_counts())

xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.2, random_state=2)

# cf = svm.SVC(kernel='linear')
# cf.fit(xtrain, ytrain)

model = RandomForestClassifier(n_estimators = 1000,random_state = 42)
model.fit(xtrain, ytrain)

yprd = model.predict(xtest)
score = accuracy_score(yprd, ytest)
print(score)
# Out:
# Head is:
#     fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0           8.94             0.507         0.29            0.90      0.031
# 1           8.42             0.681         0.19            3.33      0.012
# 2           9.65             0.362         0.35            2.24      0.159
# 3           5.63             0.278         0.50            0.90      0.099
# 4           6.49             0.474         0.59            6.77      0.142
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                  7.8                  21.9   0.9993  3.44       0.62
# 1                  1.0                  53.6   0.9953  3.36       1.10
# 2                 21.4                  62.2   0.9968  3.46       0.68
# 3                  6.3                  19.1   0.9952  3.50       0.72
# 4                 19.3                  44.9   0.9972  3.41       0.67
#
#    alcohol  quality
# 0     9.89        5
# 1    11.77        6
# ...

# %%
#Dataset 3:- House prices
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score

df2 = pd.read_csv('/content/house_prices.csv')


x = df2.drop(['price'],axis = 1)
y = df2['price']

xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size = 0.2, random_state = 2)
model = RandomForestRegressor(n_estimators=200)

model.fit(xtrain,ytrain)

ypred = model.predict(xtest)

accu = r2_score(ytest,ypred)
print("R2 Score :- ",accu)
# Out:
# R2 Score :-  0.8634254038499783

# %%
#Dataset 4:-Diabetes
df = pd.read_csv('/content/diabetes1.csv')

x = df.drop(['Outcome'], axis=1)
y = df['Outcome']

print("Head is: \n",df.head())
print("Shape is : \n",df.shape)
print(df.describe())
print(df['Outcome'].value_counts())

xtrain,ytrain,xtest,ytest = train_test_split(x,y,test_size=0.2,random_state=2)

cf = svm.SVC(kernel='linear')
cf.fit(xtrain,xtest)

model = LogisticRegression()
model.fit(xtrain,xtest)

yprd = model.predict(ytrain)
score = accuracy_score(yprd,ytest)
print(score)
# Out:
# Head is:
#     Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            4    143.7           77.7            0.0     45.9  38.1
# 1            4    195.5           67.6            0.0      0.0  37.6
# 2            5    108.7           33.2            0.0      0.0  46.3
# 3            1    106.5           76.1           22.2     22.3  26.6
# 4            7    123.8           33.8            6.9    109.5  33.7
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.370   46        0
# 1                     0.080   66        1
# 2                     0.439   23        1
# 3                     0.080   24        0
# 4                     0.197   21        1
# Shape is :
#  (768, 9)
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.010417  120.510807      65.679427      14.172656   52.170182
# ...
